# %%
import time
JANUARY = 31
FEBRUARY = 28
MARCH = 31
APRIL = 30
MAY = 31
JUNE = 30
JULY = 31
AUGUST = 31
SEPTEMBER = 30
OCTOBER = 31
NOVEMBER = 30
DECEMBER = 31

# %%
start_time = time.time()
count = 0
days = 0
for i in range(1901,2001):
    print i
    if(i % 4 == 0):
        FEBRUARY = 29
    else:
        FEBRUARY = 28
    if(days % 7 == 5):
        count += 1
        print "january"
    days += JANUARY
    if(days % 7 == 5):
        count += 1
        print "feb"
    days += FEBRUARY
    if(days % 7 == 5):
        count += 1
        print "mar"
    days += MARCH
    if(days % 7 == 5):
        count += 1
        print "april"
    days += APRIL
    if(days % 7 == 5):
        count += 1
        print "may"
    days += MAY
    if(days % 7 == 5):
        count += 1
        print "june"
    days += JUNE
    if(days % 7 == 5):
        count += 1
        print "july"
    days += JULY
    if(days % 7 == 5):
        count += 1
        print "august"
    days += AUGUST
    if(days % 7 == 5):
        count += 1
        print "september"
    days += SEPTEMBER
    if(days % 7 == 5):
        count += 1
        print "october"
    days += OCTOBER
    if(days % 7 == 5):
        count += 1
        print "november"
    days += NOVEMBER
    if(days % 7 == 5):
        count += 1
        print "december"
    days += DECEMBER

    

print count


print("Runtime: %0.3f seconds "% (time.time() - start_time))
# Out:
# 1901
# september
# december
# 1902
# june
# 1903
# feb
# mar
# november
# 1904
# may
# 1905
# january
# october
# 1906
# april
# july
# 1907
# september
# december
# 1908
# mar
# november
# 1909
# august
# 1910
# may
# 1911
# january
# october
# 1912
# september
# december
# 1913
# june
# 1914
# feb
# mar
# november
# 1915
# august
# 1916
# october
# 1917
# april
# july
# 1918
# september
# december
# 1919
# june
# 1920
# feb
# august
# 1921
# may
# 1922
# january
# october
# 1923
# april
# july
# 1924
# june
# 1925
# feb
# mar
# november
# 1926
# august
# 1927
# may
# 1928
# january
# april
# july
# 1929
# september
# december
# 1930
# june
# 1931
# feb
# mar
# november
# 1932
# may
# 1933
# january
# october
# 1934
# april
# july
# 1935
# september
# december
# 1936
# mar
# november
# 1937
# august
# 1938
# may
# 1939
# january
# october
# 1940
# september
# december
# 1941
# june
# 1942
# feb
# mar
# november
# 1943
# august
# 1944
# october
# 1945
# april
# july
# 1946
# ...
